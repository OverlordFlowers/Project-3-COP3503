# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Introduction
# This is just a simple analysis on the distribution of the variables we are considering, and my comments on them.

# %%
df = pd.read_csv("songs.csv")

# %%
dance = df['danceability']
hist = dance.hist(bins = 100)

# %% [markdown]
# From here it appears that danceability follows a standard distribution.

# %%
energy = df['energy']
hist_energy = energy.hist(bins = 100)

# %% [markdown]
# I'll run a thorough analysis later if I have time, but it looks like there's no behavior that can be seen in regards to energy.

# %%
loudness = df['loudness']
hist_loud = loudness.hist(bins = 100)
loudness.mean()
# Out:
# -11.467990038264784

# %% [markdown]
# Most songs are louder. This is a normal distribution with some skew.

# %%
speechiness = df['speechiness']
hist_speech = speechiness.hist(bins = 100)

# %% [markdown]
# This follows the example shown by the Spotify API.

# %%
tempo = df['tempo']
hist_tempo = tempo.hist(bins = 100)

# %% [markdown]
# Normal distribution.

# %%
valence = df['valence']
hist_valence = valence.hist(bins = 100)

# %% [markdown]
# No relationship.

# %%
pop = df['popularity']
hist_pop = pop.hist(bins = 100)

# %% [markdown]
# A lot of outliers w/ a popularity of 0. Then again, most songs are only listened to like... 50 people, max.
